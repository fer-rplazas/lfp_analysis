# %% [markdown]
# ## Notebook settings

# %%
# %load_ext autoreload
# %autoreload 2

# %autosave 10

# %load_ext lab_black
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Autosaving every 10 seconds
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %% [markdown]
# ## Imports

# %%
from lfp_analysis.data import *
from lfp_analysis.process import *

# %%
import numpy as np
import pandas as pd
import h5py

from pathlib import Path

import matplotlib.pyplot as plt

# %matplotlib widget

# %% [markdown]
# ## Visualization utils:

# %%
def image_hist(X):
    v_min, v_max = X.min(), X.max()
    bins = np.linspace(v_min, v_max, 400)
    hist_data = np.apply_along_axis(lambda a: np.histogram(a, bins=bins)[0], 1, X)

    plt.figure()
    plt.imshow(hist_data, aspect="auto", extent=(v_min, v_max, 2, 101))
    plt.colorbar()
    plt.show()

# %%
from PIL import Image
import PIL


def view_sample(X, idx=176, win_size=256, contiguous=7):

    cm = plt.get_cmap("viridis")
    img = Image.fromarray(
        np.uint8(cm(X[:, idx * win_size : (idx + 1 * contiguous) * win_size]) * 255)
    )

    # print(np.any(bipolar.label[idx * win_size : (idx + 1 * contiguous) * win_size]))
    return img.transpose(PIL.Image.FLIP_TOP_BOTTOM).resize((256 * contiguous, 256))

# %% [markdown]
# # Import data:

# %%
ENV = "ET1_Pegboard_OFF"
H5_SOURCE = Path(f"./data/preprocessed/{ENV}.h5")

# %%
h5 = h5py.File(H5_SOURCE, "r")
bipolar = h5["LFP"][:]
h5.close()

# %%
bipolar.shape
# Out:
# (4, 1455948)

# %%
TF = TfTransformer(bipolar).TF().power
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-8a2378f267c1> in <module>
# ----> 1 TF = TfTransformer(bipolar).TF().power
#
# /mnt/c/UsersData/Fernando/OneDrive - Nexus365/lfp_analysis/lfp_analysis/process.py in TF(self)
#      25
#      26     def TF(self):
# ---> 27         self.power = mne.time_frequency.tfr_array_morlet(
#      28             self.LFPs[np.newaxis, ...],
#      29             n_cycles=self.n_cycles,
#
# <decorator-gen-53> in tfr_array_morlet(epoch_data, sfreq, freqs, n_cycles, zero_mean, use_fft, decim, output, n_jobs, verbose)
#
# ~/anaconda3/lib/python3.8/site-packages/mne/time_frequency/tfr.py in tfr_array_morlet(epoch_data, sfreq, freqs, n_cycles, zero_mean, use_fft, decim, output, n_jobs, verbose)
#     791     .. versionadded:: 0.14.0
#     792     """
# --> 793     return _compute_tfr(epoch_data=epoch_data, freqs=freqs,
#     794                         sfreq=sfreq, method='morlet', n_cycles=n_cycles,
#     795                         zero_mean=zero_mean, time_bandwidth=None,
#
# ~/anaconda3/lib/python3.8/site-packages/mne/time_frequency/tfr.py in _compute_tfr(epoch_data, freqs, sfreq, method, n_cycles, zero_mean, time_bandwidth, use_fft, decim, output, n_jobs, verbose)
#     384
#     385     # Parallelization is applied across channels.
# --> 386     tfrs = parallel(
#     387         my_cwt(channel, Ws, output, use_fft, 'same', decim)
#     388         for channel in epoch_data.transpose(1, 0, 2))
#
# ~/anaconda3/lib/python3.8/site-packages/mne/time_frequency/tfr.py in <genexpr>(.0)
#     385     # Parallelization is applied across channels.
#     386     tfrs = parallel(
# --> 387         my_cwt(channel, Ws, output, use_fft, 'same', decim)
#     388         for channel in epoch_data.transpose(1, 0, 2))
#     389
#
# ~/anaconda3/lib/python3.8/site-packages/mne/time_frequency/tfr.py in _time_frequency_loop(X, Ws, output, use_fft, mode, decim)
#     518
#     519         # Loop across epochs
# --> 520         for epoch_idx, tfr in enumerate(coefs):
#     521             # Transform complex values
#     522             if output in ['power', 'avg_power']:
#
# ~/anaconda3/lib/python3.8/site-packages/mne/time_frequency/tfr.py in _cwt(X, Ws, mode, decim, use_fft)
#     221     for i, W in enumerate(Ws):
#     222         if use_fft:
# --> 223             fft_Ws[i] = fft(W, fsize)
#     224         if len(W) > n_times and warn_me:
#     225             msg = ('At least one of the wavelets is longer than the signal. '
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/fft/_backend.py in __ua_function__(method, args, kwargs)
#      21         if fn is None:
#      22             return NotImplemented
# ---> 23         return fn(*args, **kwargs)
#      24
#      25
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/fft/_pocketfft/basic.py in c2c(forward, x, n, axis, norm, overwrite_x, workers, plan)
#      29     out = (tmp if overwrite_x and tmp.dtype.kind == 'c' else None)
#      30
# ---> 31     return pfft.c2c(tmp, (axis,), forward, norm, out, workers)
#      32
#      33
#
# KeyboardInterrupt:

# %% [markdown]
# # Processing options:

# %%
# Raw power:
t_X = TF[0]

image_hist(t_X)
view_sample(t_X)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <PIL.Image.Image image mode=RGBA size=1792x256 at 0x7FCA8E9B7EB0>

# %%
t_X = np.log(TF[0])

image_hist(t_X)
view_sample(t_X)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <PIL.Image.Image image mode=RGBA size=1792x256 at 0x7FCA8E9476D0>

# %%
t_X = clip(zscore(np.log(TF[0])))

image_hist(t_X)
view_sample(t_X)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <PIL.Image.Image image mode=RGBA size=1792x256 at 0x7FCA8E947310>

# %%
t_X = clip(zscore((TF[0])))

image_hist(t_X)
view_sample(t_X)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <PIL.Image.Image image mode=RGBA size=1792x256 at 0x7FCA8E82BDC0>

# %%
t_X = clip(bl_correct(TF[0]))

image_hist(t_X)
view_sample(t_X)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <PIL.Image.Image image mode=RGBA size=1792x256 at 0x7FCA8E82BCA0>

# %%
t_X = clip(zscore(bl_correct(TF[0])))

image_hist(t_X)
view_sample(t_X)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <PIL.Image.Image image mode=RGBA size=1792x256 at 0x7FCA8E7C3310>

# %% [markdown]
# # Process TF:

# %%
def process(X, **kwargs):
    # X = AxisApplier(np.log)(X)
    X = AxisApplier(zscore)(X)
    X = AxisApplier(clip)(X, **kwargs)

    return X

# %%
TF = process(TF, std_factor=5)

# %%
# Quantize:
TF = np.uint8(TF * 255)

# %% [markdown]
# # Save to file:

# %%
def save_to_h5(path, TF):
    f = h5py.File(path, "w")
    f.create_dataset("TF", data=TF)
    f.close()

# %%
H5_TARGET = Path(f"./data/TF_and_df/{ENV}.h5")

# %%
save_to_h5(H5_TARGET, TF)
